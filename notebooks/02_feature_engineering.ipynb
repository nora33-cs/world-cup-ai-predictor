# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/preprocessed/clean_world_cup.csv")

# %%
df.head()
# Out:
#    year        date           stage    home_team     away_team    winner
# 0  1974  1974-06-10  Quarter-finals  South Korea        Sweden      Draw
# 1  1974  1974-06-10  Quarter-finals        Ghana   Switzerland     Ghana
# 2  1974  1974-06-10     Group Stage       Sweden  Saudi Arabia    Sweden
# 3  1974  1974-06-10     Group Stage     Cameroon       Uruguay  Cameroon
# 4  1974  1974-06-10     Group Stage      Nigeria         Japan   Nigeria

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832 entries, 0 to 831
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       832 non-null    int64
#  1   date       832 non-null    object
#  2   stage      832 non-null    object
#  3   home_team  832 non-null    object
#  4   away_team  832 non-null    object
#  5   winner     832 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 39.1+ KB

# %%
df = df.drop(columns=["date"])

# %%
X = df.drop("winner", axis=1)
y = df["winner"]

# %%
X.head()
# Out:
#    year           stage    home_team     away_team
# 0  1974  Quarter-finals  South Korea        Sweden
# 1  1974  Quarter-finals        Ghana   Switzerland
# 2  1974     Group Stage       Sweden  Saudi Arabia
# 3  1974     Group Stage     Cameroon       Uruguay
# 4  1974     Group Stage      Nigeria         Japan

# %%
y.head()
# Out:
# 0        Draw
# 1       Ghana
# 2      Sweden
# 3    Cameroon
# 4     Nigeria
# Name: winner, dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
categorical_features = ["home_team", "away_team", "stage"]

# %%
categorical_features = ["home_team", "away_team", "stage"]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ],
    remainder="passthrough"
)

# %%
X_encoded = preprocessor.fit_transform(X)

# %%
print(type(X_encoded))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
print(X_encoded.shape)
# Out:
# (832, 71)

# %%
print(df["home_team"].nunique())
print(df["away_team"].nunique())
print(df["stage"].nunique())
# Out:
# 32
# 32
# 6

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (665, 71)
# (167, 71)
# (665,)
# (167,)
